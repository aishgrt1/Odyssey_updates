# %%
import odyssey
from odyssey.core.bigquery.GithubPython import GithubPython
gp = GithubPython()
print(gp.get_count())
# Out:
# 5995653

# %%
gp_sklearn = GithubPython(package="sklearn.pipeline")
print(gp_sklearn.get_count())
# Out:
# 2125

# %%
data = gp_sklearn.get_all()

# %%
from odyssey.utils.output import pprint_ipynb

# %%
pprint_ipynb(data[0])
# Out:
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sa { color: #BA2121 } /* Literal.String.Affix */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .fm { color: #0000FF } /* Name.Function.Magic */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .vm { color: #19177C } /* Name.Variable.Magic */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="c1"># --</span>
# <span class="c1"># WIT :: String similarity example</span>
#
# <span class="kn">import</span> <span class="nn">sys</span>
# <span class="n">sys</span><span class="o">.</span><span class="n">path</span><span class="o">.</span><span class="n">append</span><span class="p">(</span><span class="s1">&#39;..&#39;</span><span class="p">)</span>
# <span class="kn">from</span> <span class="nn">wit</span> <span class="kn">import</span> <span class="o">*</span>
#
# <span class="n">num_features</span> <span class="o">=</span> <span class="mi">100</span> <span class="c1"># Characters</span>
# <span class="n">max_len</span>      <span class="o">=</span> <span class="mi">75</span>  <span class="c1"># Characters</span>
#
# <span class="c1"># Generate fake dataset</span>
# <span class="k">print</span> <span class="s1">&#39;WIT :: Generating data&#39;</span>
# <span class="n">f</span>    <span class="o">=</span> <span class="n">FakeData</span><span class="p">()</span>
# <span class="n">data</span> <span class="o">=</span> <span class="n">f</span><span class="o">.</span><span class="n">dataframe</span><span class="p">(</span><span class="n">size</span> <span class="o">=</span> <span class="mi">10000</span><span class="p">)</span>
#
# <span class="c1"># Format for keras training</span>
# <span class="k">print</span> <span class="s1">&#39;WIT :: Formatting data&#39;</span>
# <span class="n">formatter</span>   <span class="o">=</span> <span class="n">KerasFormatter</span><span class="p">(</span><span class="n">num_features</span><span class="p">,</span> <span class="n">max_len</span><span class="p">)</span>
# <span class="n">train</span><span class="p">,</span> <span class="n">levs</span> <span class="o">=</span> <span class="n">formatter</span><span class="o">.</span><span class="n">format</span><span class="p">(</span><span class="n">data</span><span class="p">,</span> <span class="p">[</span><span class="s1">&#39;obj&#39;</span><span class="p">],</span> <span class="s1">&#39;hash&#39;</span><span class="p">,</span> <span class="n">custom</span><span class="o">=</span><span class="bp">True</span><span class="p">)</span>
#
# <span class="c1"># Compile and train classifier</span>
# <span class="k">print</span> <span class="s1">&#39;WIT :: Compiling classifier&#39;</span>
# <span class="n">classifier</span> <span class="o">=</span> <span class="n">StringClassifier</span><span class="p">(</span><span class="n">train</span><span class="p">,</span> <span class="n">levs</span><span class="p">)</span>
# <span class="n">classifier</span><span class="o">.</span><span class="n">fit</span><span class="p">(</span><span class="n">batch_size</span> <span class="o">=</span> <span class="mi">1000</span><span class="p">,</span> <span class="n">nb_epoch</span> <span class="o">=</span> <span class="mi">10</span><span class="p">)</span>
#
# <span class="c1"># Create test dataset</span>
# <span class="k">print</span> <span class="s1">&#39;WIT :: Creating test dataset&#39;</span>
# <span class="n">testdata</span> <span class="o">=</span> <span class="n">f</span><span class="o">.</span><span class="n">dataframe</span><span class="p">(</span><span class="n">size</span> <span class="o">=</span> <span class="mi">1000</span><span class="p">)</span>
# <span class="n">test</span><span class="p">,</span> <span class="n">_</span>  <span class="o">=</span> <span class="n">formatter</span><span class="o">.</span><span class="n">format</span><span class="p">(</span><span class="n">testdata</span><span class="p">,</span> <span class="p">[</span><span class="s1">&#39;obj

# %%
all_sklearn_pipeline_urls = []

for i in range(len(data)):
    all_sklearn_pipeline_urls.append(data[i].get_url())

# %%
print(all_sklearn_pipeline_urls)
# Out:
# ['https://github.com/bkj/wit/tree/master/wit/examples/string-example.py', 'https://github.com/fdft/ml/tree/master/ch06/04_sent.py', 'https://github.com/fdft/ml/tree/master/ch02/seeds_knn_sklearn.py', 'https://github.com/fdft/ml/tree/master/ch02/seeds_knn_increasing_k.py', 'https://github.com/fdft/ml/tree/master/ch06/02_tuning.py', 'https://github.com/fdft/ml/tree/master/ch06/03_clean.py', 'https://github.com/fdft/ml/tree/master/ch06/01_start.py', 'https://github.com/arosh/ml/tree/master/adult/ml.py', 'https://github.com/cmry/shed/tree/master/shed/logger.py', 'https://github.com/gicsi/aap/tree/master/src/machine_learning/nltk-trainer-master/nltk_trainer/classification/args.py', 'https://github.com/oddt/oddt/tree/master/oddt/scoring/models/regressors.py', 'https://github.com/oddt/oddt/tree/master/oddt/scoring/models/classifiers.py', 'https://github.com/veg/idepi/tree/master/idepi/scripts/_discrete.py', 'https://github.com/veg/idepi/tree/master/idepi/feature_extraction/__init__.py', 'https://github.com/veg/idepi/tree/master/idepi/scripts/_learn.py', 'https://github.com/vsaw/LIRD/tree/master/lird.py', 'https://github.com/DinoV/PTVS/tree/master/Python/Product/ML/ProjectTemplates/ClassifierTemplate/classifier.py', 'https://github.com/cmry/omesa/tree/master/omesa/tools/lime_eval.py', 'https://github.com/fnl/libfnl/tree/master/scripts/fnlclassi.py', 'https://github.com/fnl/libfnl/tree/master/scripts/fnlrelex.py', 'https://github.com/hainm/MSMs/tree/master/code/tmp/plot_direction.py', 'https://github.com/hainm/MSMs/tree/master/code/tmp/do_chemical_shifts.py', 'https://github.com/hainm/MSMs/tree/master/code/tmp/test_feature_explore.py', 'https://github.com/hainm/MSMs/tree/master/code/building/do_gmm.py', 'https://github.com/hainm/MSMs/tree/master/initial_ipynbs/do_gmm_4src_n_abl/do_gmm_SMH.py', 'https://github.com/hainm/MSMs/tree/master/code/tmp/test_kmeans_trimming.py', 'https://github.com/hainm/MSMs/tree/master/code/tmp/analyze_chemical_shifts.py', 'https://github.com/hainm/MSMs/tree/master/initial_ipynbs/do_gmm_4src_n_abl/make_ensembler_fig.py', 'https://github.com/hainm/MSMs/tree/master/code/analysis/plot_structures.py', 'https://github.com/imito/odin/tree/master/odin/tests/model_test.py', 'https://github.com/lbn/kaggle/tree/master/titanic/classifier.py', 'https://github.com/mrshu/iepy/tree/master/iepy/extraction/relation_extraction_classifier.py', 'https://github.com/ntduong/ML/tree/master/ML@Hackerrank/doc_classification/solution.py', 'https://github.com/ntung/ramp/tree/master/classifier.py', 'https://github.com/vene/ambra/tree/master/scripts/semeval_reproduce_baseline.py', 'https://github.com/vene/ambra/tree/master/ambra/tools.py', 'https://github.com/vene/ambra/tree/master/scripts/semeval_reproduce_task2.py', 'https://github.com/vene/ambra/tree/master/scripts/semeval_cv.py', 'https://github.com/vene/ambra/tree/master/scripts/semeval_reproduce_task1.py', 'https://github.com/wd15/pymks/tree/master/pymks/mks_homogenization_model.py', 'https://github.com/xNUTs/PTVS/tree/master/Python/Product/ML/ProjectTemplates/ClassifierTemplate/classifier.py', 'https://github.com/yk/nlpfs14/tree/master/learntest.py', 'https://github.com/zooba/PTVS/tree/master/Python/Templates/Core/ProjectTemplates/Python/Machine Learning/ClassifierTemplate/classifier.py', 'https://github.com/PG-TUe/tpot/tree/master/tpot/gp_deap.py', 'https://github.com/PG-TUe/tpot/tree/master/tpot/export_utils.py', 'https://github.com/PG-TUe/tpot/tree/master/tpot/decorators.py', 'https://github.com/PG-TUe/tpot/tree/master/tutorials/tpot_iris_pipeline.py', 'https://github.com/PG-TUe/tpot/tree/master/tests.py', 'https://github.com/Pinafore/qb/tree/master/qanta/guesser/experimental/elasticsearch_wikidata.py', 'https://github.com/Pinafore/qb/tree/master/qanta/guesser/experimental/elasticsearch_instance_of.py', 'https://github.com/abhipec/pec/tree/master/emailApp/emailApp/views.py', 'https://github.com/dfd/sktutor/tree/master/src/sktutor/pipeline.py', 'https://github.com/dfd/sktutor/tr ...
